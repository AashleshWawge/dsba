# %%
import pandas as pd

# %%
df=pd.read_csv('dataset_Facebook.csv',sep=';')
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
photo_df=df[df['Type']=='Photo']
status_df=df[df['Type']=='Status']

# %%
photo_df.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
status_df.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
merge_data=pd.concat([status_df,photo_df])
merge_data.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1             139441  Status         2          12             3         10
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1    0.0                      10460                            19057
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sorrt=df.sort_values(by='Page total likes',ascending=False)
sorrt.head()
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 11            139441   Photo         2          12             5         10
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 11   0.0                       3112                             5590
# 6    1.0                      11692                            19479
# 7    1.0                      13720                            24137
# 4    0.0                       7244                            13594
# 5    0.0                      10472                            20849
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
tdf=df.transpose()
tdf.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %%
meltt=pd.melt(df,id_vars=['Type','Category'],
              value_vars=['Page total likes','Post Month','Post Weekday'])
meltt.head()
# Out:
#      Type  Category          variable   value
# 0   Photo         2  Page total likes  139441
# 1  Status         2  Page total likes  139441
# 2   Photo         3  Page total likes  139441
# 3   Photo         2  Page total likes  139441
# 4   Photo         2  Page total likes  139441

# %%
caste=df.pivot_table(index='Category',values='Page total likes',columns='Type',aggfunc='mean')
caste.head()
# Out:
# Type           Link          Photo         Status          Video
# Category
# 1         117984.15  123155.264865  119619.333333  135014.857143
# 2          98195.00  127099.967033  133177.947368            NaN
# 3         102112.00  118487.040000  137374.250000            NaN
